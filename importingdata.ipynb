# %% [markdown]
# FaceValue Team | Coded by Cata Santos Anzola Clemson '26
#
# https://github.com/maaghia/working-on-N2001-EMG-lab-dataset/issues/5

# %%
from IPython.display import display
import matplotlib.pyplot as plt
#matplotlib inline
import numpy as np
import os
import shutil
import posixpath
import wfdb

# %% [markdown]
# importing dataset

# %%
folder_path = r"C:/Users/catas/OneDrive - Clemson University/Uni/Bioinstrumentation Lab/FaceValue/EMGSIGNALS"
record = wfdb.rdrecord(posixpath.join(folder_path))

data_list=[]
wfdb.plot_wfdb(record=folder_path,title='N2001M01TF52')
display(folder_path.dict)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 folder_path = r"C:/Users/catas/OneDrive - Clemson University/Uni/Bioinstrumentation Lab/FaceValue/EMGSIGNALS"
# ----> 2 record = wfdb.rdrecord(posixpath.join(folder_path))
#       4 data_list=[]
#       5 wfdb.plot_wfdb(record=folder_path,title='N2001M01TF52')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\wfdb\io\record.py:2051, in rdrecord(record_name, sampfrom, sampto, channels, physical, pn_dir, m2s, smooth_frames, ignore_skew, return_res, force_channels, channel_names, warn_empty)
#    2046         dir_list = pn_dir.split("/")
#    2047         pn_dir = posixpath.join(
#    2048             dir_list[0], download.get_version(dir_list[0]), *dir_list[1:]
#    2049         )
# ...
